# %%
import tensorflow.contrib.layers as lays

def autoencoder(inputs):
    # encoder
    # 32 x 32 x 1   ->  16 x 16 x 32
    # 16 x 16 x 32  ->  8 x 8 x 16
    # 8 x 8 x 16    ->  2 x 2 x 8
    net = lays.conv2d(inputs, 32, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d(net, 16, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d(net, 8, [5, 5], stride=4, padding='SAME')
    # decoder
    # 2 x 2 x 8    ->  8 x 8 x 16
    # 8 x 8 x 16   ->  16 x 16 x 32
    # 16 x 16 x 32  ->  32 x 32 x 1
    net = lays.conv2d_transpose(net, 16, [5, 5], stride=4, padding='SAME')
    net = lays.conv2d_transpose(net, 32, [5, 5], stride=2, padding='SAME')
    net = lays.conv2d_transpose(net, 1, [5, 5], stride=2, padding='SAME', activation_fn=tf.nn.tanh)
    return net

# %% [markdown]
# Reshape and Resize a batch of images

# %%
import numpy as np
from skimage import transform

def resize_batch(imgs):
    # A function to resize a batch of MNIST images to (32, 32)
    # Args:
    #   imgs: a numpy array of size [batch_size, 28 X 28].
    # Returns:
    #   a numpy array of size [batch_size, 32, 32].
    imgs = imgs.reshape((-1, 28, 28, 1))
    resized_imgs = np.zeros((imgs.shape[0], 32, 32, 1))
    for i in range(imgs.shape[0]):
        resized_imgs[i, ..., 0] = transform.resize(imgs[i, ..., 0], (32, 32))
    return resized_imgs

# %% [markdown]
# Now we create an autoencoder, define a square error loss and an optimizer.

# %%
import tensorflow as tf

lr = 0.001

# input to the network (Messy images)
ae_inputs = tf.placeholder(tf.float32, (None, 32, 32, 1))

# create the Autoencoder network
ae_outputs = autoencoder(ae_inputs)

# calculate the loss and optimize the network
# claculate the mean square error loss
loss = tf.reduce_mean(tf.square(ae_outputs - ae_inputs))  
train_op = tf.train.AdamOptimizer(learning_rate=lr).minimize(loss)

# initialize the network
init = tf.global_variables_initializer()

# %% [markdown]
# Now we can read the batches, train the network and finally test the network by reconstructing a batch of test images.

# %%
from tensorflow.examples.tutorials.mnist import input_data
import os
import matplotlib.pyplot as plt

batch_size = 500  # Number of samples in each batch
epoch_num = 5     # Number of epochs to train the network
lr = 0.001        # Learning rate

# read MNIST dataset
mnist = input_data.read_data_sets("/home/geoffrey/ml/ML_env/converter_vhs_pal/dataset/test/", one_hot=True)

# calculate the number of batches per epoch
batch_per_ep = mnist.train.num_examples // batch_size

with tf.Session() as sess:
    sess.run(init)
    # epochs loop
    for ep in range(epoch_num):  
        # batches loop
        for batch_n in range(batch_per_ep):  
            batch_img, batch_label = mnist.train.next_batch(batch_size)  # read a batch
            batch_img = batch_img.reshape((-1, 28, 28, 1))               # reshape each sample to an (28, 28) image
            batch_img = resize_batch(batch_img)                          # reshape the images to (32, 32)
            _, c = sess.run([train_op, loss], feed_dict={ae_inputs: batch_img})
            print('Epoch: {} - cost= {:.5f}'.format((ep + 1), c))
    
    # test the trained network
    print('start test')
    batch_img, batch_label = mnist.test.next_batch(50)
    batch_img = resize_batch(batch_img)
    recon_img = sess.run([ae_outputs], feed_dict={ae_inputs: batch_img})[0]
    print('end test')
    
    # plot the reconstructed images and their ground truths (inputs)
    print('start reconstruction')
    plt.figure(1)
    plt.title('Reconstructed Images')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(recon_img[i, ..., 0], cmap='gray')
    plt.figure(2)
    plt.title('Input Images')
    for i in range(50):
        plt.subplot(5, 10, i+1)
        plt.imshow(batch_img[i, ..., 0], cmap='gray')
    plt.show()
    print('end plt show')
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /home/geoffrey/ml/ML_env/converter_vhs_pal/dataset/test/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /home/geoffrey/ml/ML_env/converter_vhs_pal/dataset/test/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /home/geoffrey/ml/ML_env/converter_vhs_pal/dataset/test/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /home/geoffrey/ml/ML_env/converter_vhs_pal/dataset/test/t10k-labels-idx1-ubyte.gz
# /home/geoffrey/ml/ML_env/lib/python3.5/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/geoffrey/ml/ML_env/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Epoch: 1 - cost= 0.10009
# Epoch: 1 - cost= 0.10087
# Epoch: 1 - cost= 0.10181
# Epoch: 1 - cost= 0.09659
# Epoch: 1 - cost= 0.09532
# Epoch: 1 - cost= 0.09505
# Epoch: 1 - cost= 0.09063
# Epoch: 1 - cost= 0.08652
# Epoch: 1 - cost= 0.08317
# Epoch: 1 - cost= 0.08007
# Epoch: 1 - cost= 0.07680
# Epoch: 1 - cost= 0.07935
# Epoch: 1 - cost= 0.07735
# Epoch: 1 - cost= 0.07378
# Epoch: 1 - cost= 0.07097
# Epoch: 1 - cost= 0.06995
# Epoch: 1 - cost= 0.06862
# Epoch: 1 - cost= 0.06714
# Epoch: 1 - cost= 0.06716
# Epoch: 1 - cost= 0.06546
# Epoch: 1 - cost= 0.06573
# Epoch: 1 - cost= 0.06403
# Epoch: 1 - cost= 0.06242
# Epoch: 1 - cost= 0.06323
# Epoch: 1 - cost= 0.06325
# Epoch: 1 - cost= 0.06115
# Epoch: 1 - cost= 0.06122
# Epoch: 1 - cost= 0.06033
# Epoch: 1 - cost= 0.05859
# Epoch: 1 - cost= 0.05994
# Epoch: 1 - cost= 0.05686
# Epoch: 1 - cost= 0.05695
# Epoch: 1 - cost= 0.05819
# Epoch: 1 - cost= 0.05582
# Epoch: 1 - cost= 0.05647
# Epoch: 1 - cost= 0.05468
# Epoch: 1 - cost= 0.05489
# Epoch: 1 - cost= 0.05439
# Epoch: 1 - cost= 0.05366
# Epoch: 1 - cost= 0.05460
# Epoch: 1 - cost= 0.05505
# Epoch: 1 - cost= 0.05412
# Epoch: 1 - cost= 0.05338
# Epoch: 1 - cost= 0.05322
# Epoch: 1 - cost= 0.05352
# Epoch: 1 - cost= 0.05272
# Epoch: 1 - cost= 0.05274
# Epoch: 1 - cost= 0.05166
# Epoch: 1 - cost= 0.05153
# Epoch: 1 - cost= 0.05003
# Epoch: 1 - cost= 0.05017
# Epoch: 1 - cost= 0.05002
# Epoch: 1 - cost= 0.05012
# Epoch: 1 - cost= 0.05069
# Epoch: 1 - cost= 0.04935
# Epoch: 1 - cost= 0.04850
# Epoch: 1 - cost= 0.04996
# Epoch: 1 - cost= 0.04840
# Epoch: 1 - cost= 0.04822
# Epoch: 1 - cost= 0.04679
# Epoch: 1 - cost= 0.04705
# Epoch: 1 - cost= 0.04729
# Epoch: 1 - cost= 0.04574
# Epoch: 1 - cost= 0.04702
# Epoch: 1 - cost= 0.04512
# Epoch: 1 - cost= 0.04404
# Epoch: 1 - cost= 0.04343
# Epoch: 1 - cost= 0.04315
# Epoch: 1 - cost= 0.04268
# Epoch: 1 - cost= 0.04189
# Epoch: 1 - cost= 0.04147
# Epoch: 1 - cost= 0.04066
# Epoch: 1 - cost= 0.04044
# Epoch: 1 - cost= 0.04008
# Epoch: 1 - cost= 0.03948
# Epoch: 1 - cost= 0.03910
# Epoch: 1 - cost= 0.03814
# Epoch: 1 - cost= 0.03743
# Epoch: 1 - cost= 0.03686
# Epoch: 1 - cost= 0.03660
# Epoch: 1 - cost= 0.03537
# Epoch: 1 - cost= 0.03618
# Epoch: 1 - cost= 0.03587
# Epoch: 1 - cost= 0.03446
# Epoch: 1 - cost= 0.03497
# Epoch: 1 - cost= 0.03401
# Epoch: 1 - cost= 0.03341
# Epoch: 1 - cost= 0.03351
# Epoch: 1 - cost= 0.03239
# Epoch: 1 - cost= 0.03263
# Epoch: 1 - cost= 0.03204
# Epoch: 1 - cost= 0.03176
# Epoch: 1 - cost= 0.03136
# Epoch: 1 - cost= 0.03053
# Epoch: 1 - cost= 0.03049
# Epoch: 1 - cost= 0.03036
# Epoch: 1 - cost= 0.03023
# Epoch: 1 - cost= 0.02871
# Epoch: 1 - cost= 0.02943
# Epoch: 1 - cost= 0.02884
# Epoch: 1 - cost= 0.02819
# Epoch: 1 - cost= 0.02743
# Epoch: 1 - cost= 0.02781
# Epoch: 1 - cost= 0.02724
# Epoch: 1 - cost= 0.02728
# Epoch: 1 - cost= 0.02698
# Epoch: 1 - cost= 0.02676
# Epoch: 1 - cost= 0.02579
# Epoch: 1 - cost= 0.02609
# Epoch: 1 - cost= 0.02648
# Epoch: 2 - cost= 0.02474
# Epoch: 2 - cost= 0.02523
# Epoch: 2 - cost= 0.02494
# Epoch: 2 - cost= 0.02478
# Epoch: 2 - cost= 0.02450
# Epoch: 2 - cost= 0.02374
# Epoch: 2 - cost= 0.02358
# Epoch: 2 - cost= 0.02350
# Epoch: 2 - cost= 0.02321
# Epoch: 2 - cost= 0.02285
# Epoch: 2 - cost= 0.02329
# Epoch: 2 - cost= 0.02260
# Epoch: 2 - cost= 0.02226
# Epoch: 2 - cost= 0.02216
# Epoch: 2 - cost= 0.02207
# Epoch: 2 - cost= 0.02126
# Epoch: 2 - cost= 0.02144
# Epoch: 2 - cost= 0.02105
# Epoch: 2 - cost= 0.02095
# Epoch: 2 - cost= 0.02125
# Epoch: 2 - cost= 0.02093
# Epoch: 2 - cost= 0.02113
# Epoch: 2 - cost= 0.02041
# Epoch: 2 - cost= 0.02040
# Epoch: 2 - cost= 0.02062
# Epoch: 2 - cost= 0.02023
# Epoch: 2 - cost= 0.02025
# Epoch: 2 - cost= 0.02014
# Epoch: 2 - cost= 0.01992
# Epoch: 2 - cost= 0.01930
# Epoch: 2 - cost= 0.01932
# Epoch: 2 - cost= 0.01882
# Epoch: 2 - cost= 0.01941
# Epoch: 2 - cost= 0.01860
# Epoch: 2 - cost= 0.01896
# Epoch: 2 - cost= 0.01911
# Epoch: 2 - cost= 0.01880
# Epoch: 2 - cost= 0.01787
# Epoch: 2 - cost= 0.01864
# Epoch: 2 - cost= 0.01876
# Epoch: 2 - cost= 0.01810
# Epoch: 2 - cost= 0.01724
# Epoch: 2 - cost= 0.01750
# Epoch: 2 - cost= 0.01762
# Epoch: 2 - cost= 0.01780
# Epoch: 2 - cost= 0.01713
# Epoch: 2 - cost= 0.01722
# Epoch: 2 - cost= 0.01761
# Epoch: 2 - cost= 0.01720
# Epoch: 2 - cost= 0.01727
# Epoch: 2 - cost= 0.01677
# Epoch: 2 - cost= 0.01691
# Epoch: 2 - cost= 0.01662
# Epoch: 2 - cost= 0.01692
# Epoch: 2 - cost= 0.01673
# Epoch: 2 - cost= 0.01646
# Epoch: 2 - cost= 0.01557
# Epoch: 2 - cost= 0.01615
# Epoch: 2 - cost= 0.01566
# Epoch: 2 - cost= 0.01572
# Epoch: 2 - cost= 0.01613
# Epoch: 2 - cost= 0.01560
# Epoch: 2 - cost= 0.01564
# Epoch: 2 - cost= 0.01508
# Epoch: 2 - cost= 0.01596
# Epoch: 2 - cost= 0.01552
# Epoch: 2 - cost= 0.01523
# Epoch: 2 - cost= 0.01532
# Epoch: 2 - cost= 0.01483
# Epoch: 2 - cost= 0.01492
# Epoch: 2 - cost= 0.01428
# Epoch: 2 - cost= 0.01533
# Epoch: 2 - cost= 0.01467
# Epoch: 2 - cost= 0.01423
# Epoch: 2 - cost= 0.01429
# Epoch: 2 - cost= 0.01508
# Epoch: 2 - cost= 0.01447
# Epoch: 2 - cost= 0.01448
# Epoch: 2 - cost= 0.01454
# Epoch: 2 - cost= 0.01460
# Epoch: 2 - cost= 0.01420
# Epoch: 2 - cost= 0.01460
# Epoch: 2 - cost= 0.01432
# Epoch: 2 - cost= 0.01435
# Epoch: 2 - cost= 0.01413
# Epoch: 2 - cost= 0.01410
# Epoch: 2 - cost= 0.01379
# Epoch: 2 - cost= 0.01426
# Epoch: 2 - cost= 0.01405
# Epoch: 2 - cost= 0.01337
# Epoch: 2 - cost= 0.01408
# Epoch: 2 - cost= 0.01376
# Epoch: 2 - cost= 0.01382
# Epoch: 2 - cost= 0.01346
# Epoch: 2 - cost= 0.01371
# Epoch: 2 - cost= 0.01346
# Epoch: 2 - cost= 0.01365
# Epoch: 2 - cost= 0.01350
# Epoch: 2 - cost= 0.01312
# Epoch: 2 - cost= 0.01353
# Epoch: 2 - cost= 0.01319
# Epoch: 2 - cost= 0.01328
# Epoch: 2 - cost= 0.01356
# Epoch: 2 - cost= 0.01347
# Epoch: 2 - cost= 0.01286
# Epoch: 2 - cost= 0.01346
# Epoch: 2 - cost= 0.01278
# Epoch: 2 - cost= 0.01348
# Epoch: 2 - cost= 0.01275
# Epoch: 2 - cost= 0.01290
# Epoch: 3 - cost= 0.01292
# Epoch: 3 - cost= 0.01286
# Epoch: 3 - cost= 0.01251
# Epoch: 5 - cost= 0.00830
# Epoch: 5 - cost= 0.00860
# Epoch: 5 - cost= 0.00808
# Epoch: 5 - cost= 0.00825
# Epoch: 5 - cost= 0.00840
# Epoch: 5 - cost= 0.00854
# Epoch: 5 - cost= 0.00807
# Epoch: 5 - cost= 0.00822
# Epoch: 5 - cost= 0.00848
# Epoch: 5 - cost= 0.00831
# Epoch: 5 - cost= 0.00802
# Epoch: 5 - cost= 0.00819
# Epoch: 5 - cost= 0.00865
# Epoch: 5 - cost= 0.00840
# Epoch: 5 - cost= 0.00807
# Epoch: 5 - cost= 0.00825
# Epoch: 5 - cost= 0.00808
# Epoch: 5 - cost= 0.00804
# Epoch: 5 - cost= 0.00794
# Epoch: 5 - cost= 0.00802
# Epoch: 5 - cost= 0.00794
# Epoch: 5 - cost= 0.00803
# Epoch: 5 - cost= 0.00789
# Epoch: 5 - cost= 0.00820
# Epoch: 5 - cost= 0.00816
# Epoch: 5 - cost= 0.00797
# Epoch: 5 - cost= 0.00792
# Epoch: 5 - cost= 0.00780
# Epoch: 5 - cost= 0.00849
# Epoch: 5 - cost= 0.00820
# Epoch: 5 - cost= 0.00766
# Epoch: 5 - cost= 0.00830
# Epoch: 5 - cost= 0.00762
# Epoch: 5 - cost= 0.00806
# Epoch: 5 - cost= 0.00797
# Epoch: 5 - cost= 0.00807
# Epoch: 5 - cost= 0.00827
# Epoch: 5 - cost= 0.00782
# Epoch: 5 - cost= 0.00826
# Epoch: 5 - cost= 0.00814
# Epoch: 5 - cost= 0.00800
# Epoch: 5 - cost= 0.00796
# Epoch: 5 - cost= 0.00829
# Epoch: 5 - cost= 0.00797
# Epoch: 5 - cost= 0.00818
# Epoch: 5 - cost= 0.00814
# Epoch: 5 - cost= 0.00820
# Epoch: 5 - cost= 0.00802
# Epoch: 5 - cost= 0.00783
# Epoch: 5 - cost= 0.00802
# Epoch: 5 - cost= 0.00803
# Epoch: 5 - cost= 0.00787
# Epoch: 5 - cost= 0.00795
# Epoch: 5 - cost= 0.00807
# Epoch: 5 - cost= 0.00809
# Epoch: 5 - cost= 0.00785
# Epoch: 5 - cost= 0.00809
# Epoch: 5 - cost= 0.00790
# Epoch: 5 - cost= 0.00809
# Epoch: 5 - cost= 0.00795
# Epoch: 5 - cost= 0.00782
# Epoch: 5 - cost= 0.00821
# Epoch: 5 - cost= 0.00785
# Epoch: 5 - cost= 0.00785
# Epoch: 5 - cost= 0.00795
# Epoch: 5 - cost= 0.00784
# Epoch: 5 - cost= 0.00742
# Epoch: 5 - cost= 0.00757
# Epoch: 5 - cost= 0.00764
# Epoch: 5 - cost= 0.00802
# Epoch: 5 - cost= 0.00781
# Epoch: 5 - cost= 0.00779
# Epoch: 5 - cost= 0.00776
# Epoch: 5 - cost= 0.00781
# Epoch: 5 - cost= 0.00776
# Epoch: 5 - cost= 0.00773
# Epoch: 5 - cost= 0.00766
# Epoch: 5 - cost= 0.00802
# Epoch: 5 - cost= 0.00756
# Epoch: 5 - cost= 0.00790
# Epoch: 5 - cost= 0.00790
# Epoch: 5 - cost= 0.00769
